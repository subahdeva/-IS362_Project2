# %%
import numpy as np
import pandas as pd
import re

# FBI Data of Offenses in California by County
# 1) Which counties have the highest number of violent crimes?
# 2) Which counties have the lowest number of violent crimes?
# 3) Which counties have the highest number of murder and nonnegligent manslaughter (manm)?


#Load CSV file and read all rows
df = pd.read_csv("ca_offenses_by_county_untidy.csv", index_col = False,)

#Clean up county names by removing any digits within each word
df['county'] = df['county'].str.replace('\d+', '')

#Create a custom clean header with Proper wording for each column to clearly distinguish each column of data
csv_header = ['County Type', 'County', 'Violent Crimes', 'Rape', 'Robbery', 'Murder and Non-Negligent Manslaughter', 
              'Aggravated Assault', 'Property crime', 'Burglaries', 'Larceny-theft', 'Motor Vehicle Theft', 'Arson'] 

#Write to new csv with the clean-up
df.to_csv('ca_offenses_by_county_tidy.csv', header=csv_header, index=False, mode= 'w')

#Reload CSV file and to read new csv
df = pd.read_csv('ca_offenses_by_county_tidy.csv',na_filter= False, skipinitialspace=True)

#uncomment out to check what columns are objects or integers
#df.info()

#display sorted csv
df.head(60)
# Out:
#                  County Type           County  Violent Crimes  Rape  Robbery  \
# 0      Metropolitan Counties           Fresno             962     8       32
# 1      Metropolitan Counties            Marin              95     3        5
# 2      Metropolitan Counties   San Bernardino             920    18       91
# 3   Nonmetropolitan Counties           Alpine               9     0        0
# 4   Nonmetropolitan Counties         Mariposa              89     0        8
# 5      Metropolitan Counties        Riverside             885    12       38
# 6      Metropolitan Counties             Yolo              87     1       13
# 7      Metropolitan Counties      San Joaquin             845     5       18
# 8   Nonmetropolitan Counties           Plumas              82     1       12
# 9      Metropolitan Counties             Napa              79     1       13
# 10     Metropolitan Counties           Shasta             697     3       69
# 11     Metropolitan Counties           Sonoma             638     5       73
# 12  Nonmetropolitan Counties             Inyo              58     0        7
# 13     Metropolitan Counties          Alameda             510     6       13
# 14  Nonmetropolitan Counties           Amador              50     1        2
# 15     Metropolitan Counties      Los Angeles            5173    98      304
# 16  Nonmetropolitan Counties           Lassen              47     0        3
# 17  Nonmetropolitan Counties            Glenn              44     1        2
# 18     Metropolitan Counties           Merced             432    10       20
# 19     Metropolitan Counties     Contra Costa             426    14       24
# 20     Metropolitan Counties       San Benito              41     1        4
# 21     Metropolitan Counties       Stanislaus             394    11       35
# 22  Nonmetropolitan Counties         Siskiyou              39     2        4
# 23     Metropolitan Counties           Tulare             383    23       29
# 24  Nonmetropolitan Counties            Modoc              34     0        1
# 25  Nonmetropolitan Counties          Trinity              34     1        6
# 26     Metropolitan Counties           Madera             334     1       18
# 27     Metropolitan Counties        San Mateo             330     3       53
# 28  Nonmetropolitan Counties           Colusa              33     0        2
# 29     Metropolitan Counties  San Luis Obispo             324     3       17
# 30  Nonmetropolitan Counties        Mendocino             324     5       56
# 31     Metropolitan Counties       Sacramento            3117    37      155
# 32  Nonmetropolitan Counties           Sierra               3     0        0
# 33     Metropolitan Counties           Placer             299     4       20
# 34     Metropolitan Counties       Santa Cruz             295     0       25
# 35     Metropolitan Counties    Santa Barbara             266     2       29
# 36  Nonmetropolitan Counties         Humboldt             265     7       18
# 37     Metropolitan Counties        El Dorado             252     9       46
# 38     Metropolitan Counties         Monterey             244     5       31
# 39     Metropolitan Counties      Santa Clara             232     4       36
# 40     Metropolitan Counties             Yuba             227     3       19
# 41     Metropolitan Counties         Imperial             219     0        6
# 42     Metropolitan Counties           Orange             213     2       12
# 43  Nonmetropolitan Counties             Lake             200     3       16
# 44     Metropolitan Counties             Kern            2235    31      157
# 45  Nonmetropolitan Counties         Tuolumne             185     0       49
# 46     Metropolitan Counties          Ventura             169     3       32
# 47  Nonmetropolitan Counties           Tehama             167     3        5
# 48     Metropolitan Counties            Butte             155     4       20
# 49  Nonmetropolitan Counties             Mono              14     0        1
# 50  Nonmetropolitan Counties           Nevada             139     0       10
# 51     Metropolitan Counties            Kings             122     2       16
# 52  Nonmetropolitan Counties        Calaveras             111     6       24
# 53     Metropolitan Counties           Sutter             104     1        9
# 54  Nonmetropolitan Counties        Del Norte             101     1       21
# 55     Metropolitan Counties           Solano             101     3        7
# 56     Metropolitan Counties        San Diego            1161    10      110
#
#     Murder and Non-Negligent Manslaughter  Aggravated Assault  Property crime  \
# 0                                     112                 810            3810
# 1                                      20                  67             746
# 2                                     141                 670            5527
# 3                                       0                   9              35
# 4                                       1                  80             268
# 5                                     172                 663            7680
# 6                                       5                  68             309
# 7                                     161                 661            3564
# 8                                       4                  65             271
# 9                                       3                  62             278
# 10                                     26                 599             958
# 11                                     58                 502            1468
# 12                                      7                  44             107
# 13                                    177                 314            2077
# 14                                      5                  42             340
# 15                                   1212                3559           16301
# 16                                      3                  41             200
# 17                                      3                  38             165
# 18                                     30                 372            1605
# 19                                    153                 235            2013
# 20                                      4                  32             173
# 21                                    122                 226            2123
# 22                                      6                  27             158
# 23                                     64                 267            2075
# 24                                      0                  33              54
# 25                                      5                  22             187
# 26                                     26                 289            1252
# 27                                     90                 184            2796
# 28                                      0                  31             166
# 29                                     15                 289            1347
# 30                                     20                 243             451
# 31                                   1026                1899           11164
# 32                                      0                   3              31
# 33                                     36                 239            1659
# 34                                     40                 230            1935
# 35                                     32                 203            1676
# 36                                     45                 195             760
# 37                                     32                 165            2031
# 38                                     48                 160            1246
# 39                                     24                 168            1358
# 40                                     40                 165            1223
# 41                                      7                 206             625
# 42                                     28                 171            1265
# 43                                     17                 164             837
# 44                                    360                1687            9903
# 45                                     22                 114             749
# 46                                     16                 118             849
# 47                                      1                 158             249
# 48                                     14                 117            1422
# 49                                      2                  11              42
# 50                                      8                 121             716
# 51                                      9                  95             470
# 52                                      8                  73             656
# 53                                     10                  84             562
# 54                                     13                  66             380
# 55                                     14                  77             404
# 56                                    161                 880            4784
#
#     Burglaries  Larceny-theft  Motor Vehicle Theft  Arson
# 0         1398           1838                  574    145
# 1          189            554                    3      4
# 2         1719           2583                 1225     62
# 3           15             19                    1      0
# 4           77            189                    2      0
# 5         1880           4321                 1479     18
# 6          109            185                   15      6
# 7         1039           2381                  144     30
# 8          111            156                    4      0
# 9          107            170                    1      0
# 10         423            489                   46     23
# 11         517            937                   14     19
# 12          41             65                    1      0
# 13         463            985                  629     11
# 14         130            205                    5      1
# 15        3739           8359                 4203    215
# 16          78            122                    0      3
# 17          74             89                    2      2
# 18         596            955                   54     10
# 19         660           1332                   21     18
# 20          57            106                   10      0
# 21         884           1188                   51     14
# 22          70             79                    9      0
# 23         750           1325                    0      0
# 24          18             36                    0      0
# 25          94             90                    3      0
# 26         556            686                   10      4
# 27         467           1953                  376     15
# 28          49            116                    1      0
# 29         461            873                   13      3
# 30         215            230                    6     10
# 31        3690           7348                  126     31
# 32           5             23                    3      0
# 33         454           1163                   42      4
# 34         604           1323                    8     15
# 35         511           1152                   13     12
# 36         371            358                   31     12
# 37         577           1412                   42      4
# 38         347            872                   27     12
# 39         261            899                  198      3
# 40         417            799                    7     11
# 41         202            395                   28     21
# 42         244            879                  142     11
# 43         380            452                    5     13
# 44        3243           4777                 1883    300
# 45         413            330                    6      2
# 46         236            530                   83     15
# 47         173             75                    1     14
# 48         708            693                   21      0
# 49          16             25                    1      0
# 50         380            321                   15      5
# 51         193            265                   12      5
# 52         251            386                   19      0
# 53         185            332                   45      4
# 54         194            182                    4     13
# 55         186            176                   42      9
# 56        1153           2843                  788     41

# %%
# 1) Los Angeles, Sacramento, Kern, and San Diego are some of the top counties in California 
# with the highest numbers in violent crime
df[['County', 'Violent Crimes']].sort_values('Violent Crimes', ascending=False).head(10)
# Out:
#             County  Violent Crimes
# 15     Los Angeles            5173
# 31      Sacramento            3117
# 44            Kern            2235
# 56       San Diego            1161
# 0           Fresno             962
# 2   San Bernardino             920
# 5        Riverside             885
# 7      San Joaquin             845
# 10          Shasta             697
# 11          Sonoma             638

# %%
# 2) Sierra, Alpine, and Mono are the top 3 counties in California with the lowest number of violent crimes

df[['County', 'Violent Crimes']].sort_values('Violent Crimes', ascending=True).head(10)
# Out:
#         County  Violent Crimes
# 32      Sierra               3
# 3       Alpine               9
# 49        Mono              14
# 28      Colusa              33
# 24       Modoc              34
# 25     Trinity              34
# 22    Siskiyou              39
# 20  San Benito              41
# 17       Glenn              44
# 16      Lassen              47

# %%
# 3) Los Angeles, Sacramento, and Kern are the top 3 counties in California with the highest number of murder and nonnegligent manslaughter 
df[['County', 'Murder and Non-Negligent Manslaughter']].sort_values('Murder and Non-Negligent Manslaughter', ascending=False).head(10)
# Out:
#             County  Murder and Non-Negligent Manslaughter
# 15     Los Angeles                                   1212
# 31      Sacramento                                   1026
# 44            Kern                                    360
# 13         Alameda                                    177
# 5        Riverside                                    172
# 56       San Diego                                    161
# 7      San Joaquin                                    161
# 19    Contra Costa                                    153
# 2   San Bernardino                                    141
# 21      Stanislaus                                    122
